# %% [markdown]
# <a href="https://colab.research.google.com/github/cam2149/eda_couse/blob/main/merge_join.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este cuaderno se basa en el cuaderno de Python Data Science Handbook de Jake VanderPlas
# *El texto se publica bajo la licencia CC-BY-NC-ND, y el código se publica bajo la licencia MIT.

# %% [markdown]
# # Combinando conjuntos de datos: Combinar y unir

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### One-to-one joins

# %%
dfEmpleadoGrupo1 = pd.DataFrame({'Empleado': ['Juan', 'Jose', 'Luis', 'Santiago'],
                    'Grupo': ['Contabilidad', 'Ingeniería', 'Ingeniería', 'Recursos Humanos']})
dfEmpleadoAnioIngreso2 = pd.DataFrame({'Empleado': ['Luis', 'Juan', 'Jose', 'Santiago'],
                    'AnioIngreso': [2004, 2008, 2012, 2014]})

print("dfEmpleadoGrupo1 \n",dfEmpleadoGrupo1)

print(" ")

print("dfEmpleadoAnioIngreso2 \n",dfEmpleadoAnioIngreso2)
# Out:
# dfEmpleadoGrupo1
#     Empleado             Grupo
# 0      Juan      Contabilidad
# 1      Jose        Ingeniería
# 2      Luis        Ingeniería
# 3  Santiago  Recursos Humanos
#
# dfEmpleadoAnioIngreso2
#     Empleado  AnioIngreso
# 0      Luis         2004
# 1      Juan         2008
# 2      Jose         2012
# 3  Santiago         2014

# %% [markdown]
# Unir un solo dataframe

# %%
dfMergeGrupoAnioIngreso3 = pd.merge(dfEmpleadoGrupo1 , dfEmpleadoAnioIngreso2 )
dfMergeGrupoAnioIngreso3
# Out:
#    Empleado             Grupo  AnioIngreso
# 0      Juan      Contabilidad         2008
# 1      Jose        Ingeniería         2012
# 2      Luis        Ingeniería         2004
# 3  Santiago  Recursos Humanos         2014

# %% [markdown]
# # Many-to-one joins
#
# Se preservan los duplicados

# %%
dfGrupoSupervisor4 = pd.DataFrame({'Grupo': ['Contabilidad', 'Ingeniería', 'Recursos Humanos'],
                    'Supervisor': ['Carlos', 'Guido', 'Esteban']})
pd.merge(dfMergeGrupoAnioIngreso3, dfGrupoSupervisor4)
# Out:
#    Empleado             Grupo  AnioIngreso Supervisor
# 0      Juan      Contabilidad         2008     Carlos
# 1      Jose        Ingeniería         2012      Guido
# 2      Luis        Ingeniería         2004      Guido
# 3  Santiago  Recursos Humanos         2014    Esteban

# %% [markdown]
# Se repite la información del supervisor

# %% [markdown]
# ### Many-to-many joins

# %% [markdown]
# Las uniones de muchos a muchos son un concepto un poco confuso conceptualmente, pero están bien definidas.
# Si la columna clave tanto en el array izquierdo como en el derecho contiene duplicados, entonces el resultado es una unión de muchos a muchos.
# Esto será quizás más claro con un ejemplo concreto.
# Consideremos lo siguiente, donde tenemos un ``DataFrame`` que muestra una o más habilidades asociadas con un grupo en particular.
# Al realizar una unión de muchos a muchos, podemos recuperar las habilidades asociadas con cualquier persona individual:

# %%
class display(object):
    """Display HTML representation of multiple objects"""
    template = """
    {0}{1}
    """
    def __init__(self, *args):
        self.args = args

    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)

    def __repr__(self):
        return '\n\n'.join(a + '\n' + repr(eval(a))
                           for a in self.args)



dfGrupoHabilidades5 = pd.DataFrame({'Grupo': ['Contabilidad', 'Contabilidad',
                              'Ingeniería', 'Ingeniería', 'Recursos Humanos', 'Recursos Humanos'],
                    'Habilidades': ['matemática', 'excel', 'codificación', 'linux',
                               'excel', 'organización']})
display('dfEmpleadoGrupo1', 'dfGrupoHabilidades5', "pd.merge(dfEmpleadoGrupo1, dfGrupoHabilidades5)")
# Out:
# dfEmpleadoGrupo1
#    Empleado             Grupo
# 0      Juan      Contabilidad
# 1      Jose        Ingeniería
# 2      Luis        Ingeniería
# 3  Santiago  Recursos Humanos
#
# dfGrupoHabilidades5
#               Grupo   Habilidades
# 0      Contabilidad    matemática
# 1      Contabilidad         excel
# 2        Ingeniería  codificación
# 3        Ingeniería         linux
# 4  Recursos Humanos         excel
# 5  Recursos Humanos  organización
#
# pd.merge(dfEmpleadoGrupo1, dfGrupoHabilidades5)
#    Empleado             Grupo   Habilidades
# 0      Juan      Contabilidad    matemática
# 1      Juan      Contabilidad         excel
# 2      Jose        Ingeniería  codificación
# 3      Jose        Ingeniería         linux
# 4      Luis        Ingeniería  codificación
# 5      Luis        Ingeniería         linux
# 6  Santiago  Recursos Humanos         excel
# 7  Santiago  Recursos Humanos  organización

# %% [markdown]
# ## Specification of the Merge Key

# %% [markdown]
# ### The ``on`` keyword
# ``on`` usa el nombre de la columna

# %%
display('dfEmpleadoGrupo1', 'dfEmpleadoAnioIngreso2', "pd.merge(dfEmpleadoGrupo1, dfEmpleadoAnioIngreso2, on='Empleado')")
# Out:
# dfEmpleadoGrupo1
#    Empleado             Grupo
# 0      Juan      Contabilidad
# 1      Jose        Ingeniería
# 2      Luis        Ingeniería
# 3  Santiago  Recursos Humanos
#
# dfEmpleadoAnioIngreso2
#    Empleado  AnioIngreso
# 0      Luis         2004
# 1      Juan         2008
# 2      Jose         2012
# 3  Santiago         2014
#
# pd.merge(dfEmpleadoGrupo1, dfEmpleadoAnioIngreso2, on='Empleado')
#    Empleado             Grupo  AnioIngreso
# 0      Juan      Contabilidad         2008
# 1      Jose        Ingeniería         2012
# 2      Luis        Ingeniería         2004
# 3  Santiago  Recursos Humanos         2014

# %% [markdown]
# Esto funciona si ambas tienen el mismo nombre

# %% [markdown]
# ### The ``left_on`` and ``right_on`` keywords
#
# Cuando las columnas no se llaman igual

# %%
dfNombreSalario3 = pd.DataFrame({'Nombre': ['Juan', 'Jose', 'Luis', 'Santiago'],
                    'Salario': [70000, 80000, 120000, 90000]})
display('dfEmpleadoGrupo1', 'dfNombreSalario3', 'pd.merge(dfEmpleadoGrupo1, dfNombreSalario3, left_on="Empleado", right_on="Nombre")')
# Out:
# dfEmpleadoGrupo1
#    Empleado             Grupo
# 0      Juan      Contabilidad
# 1      Jose        Ingeniería
# 2      Luis        Ingeniería
# 3  Santiago  Recursos Humanos
#
# dfNombreSalario3
#      Nombre  Salario
# 0      Juan    70000
# 1      Jose    80000
# 2      Luis   120000
# 3  Santiago    90000
#
# pd.merge(dfEmpleadoGrupo1, dfNombreSalario3, left_on="Empleado", right_on="Nombre")
#    Empleado             Grupo    Nombre  Salario
# 0      Juan      Contabilidad      Juan    70000
# 1      Jose        Ingeniería      Jose    80000
# 2      Luis        Ingeniería      Luis   120000
# 3  Santiago  Recursos Humanos  Santiago    90000

# %% [markdown]
# Se puede borrar la columna extra

# %%
pd.merge(dfEmpleadoGrupo1, dfNombreSalario3, left_on="Empleado", right_on="Nombre").drop('Nombre', axis=1)
# Out:
#    Empleado             Grupo  Salario
# 0      Juan      Contabilidad    70000
# 1      Jose        Ingeniería    80000
# 2      Luis        Ingeniería   120000
# 3  Santiago  Recursos Humanos    90000

# %% [markdown]
# ### The ``left_index`` and ``right_index`` keywords
#
# Sometimes, rather than merging on a column, you would instead like to merge on an index.
# For example, your data might look like this:

# %%
dfEmpleadoGrupo1a = dfEmpleadoGrupo1.set_index('Empleado')
dfEmpleadoAnioIngreso2a = dfEmpleadoAnioIngreso2.set_index('Empleado')
display('dfEmpleadoGrupo1a', 'dfEmpleadoAnioIngreso2a')
# Out:
# dfEmpleadoGrupo1a
#                      Grupo
# Empleado
# Juan          Contabilidad
# Jose            Ingeniería
# Luis            Ingeniería
# Santiago  Recursos Humanos
#
# dfEmpleadoAnioIngreso2a
#           AnioIngreso
# Empleado
# Luis             2004
# Juan             2008
# Jose             2012
# Santiago         2014

# %% [markdown]
#  ``left_index`` y ``right_index`` en  ``pd.merge()``:

# %%
display('dfEmpleadoGrupo1a', 'dfEmpleadoAnioIngreso2a',
        "pd.merge(dfEmpleadoGrupo1a, dfEmpleadoAnioIngreso2a, left_index=True, right_index=True)")
# Out:
# dfEmpleadoGrupo1a
#                      Grupo
# Empleado
# Juan          Contabilidad
# Jose            Ingeniería
# Luis            Ingeniería
# Santiago  Recursos Humanos
#
# dfEmpleadoAnioIngreso2a
#           AnioIngreso
# Empleado
# Luis             2004
# Juan             2008
# Jose             2012
# Santiago         2014
#
# pd.merge(dfEmpleadoGrupo1a, dfEmpleadoAnioIngreso2a, left_index=True, right_index=True)
#                      Grupo  AnioIngreso
# Empleado
# Juan          Contabilidad         2008
# Jose            Ingeniería         2012
# Luis            Ingeniería         2004
# Santiago  Recursos Humanos         2014

# %% [markdown]
#  ``DataFrame`` implementa el ``join()`` que hace un  ``merge`` con los indices:

# %%
display('dfEmpleadoGrupo1a', 'dfEmpleadoAnioIngreso2a', 'dfEmpleadoGrupo1a.join(dfEmpleadoAnioIngreso2a)')
# Out:
# dfEmpleadoGrupo1a
#                      Grupo
# Empleado
# Juan          Contabilidad
# Jose            Ingeniería
# Luis            Ingeniería
# Santiago  Recursos Humanos
#
# dfEmpleadoAnioIngreso2a
#           AnioIngreso
# Empleado
# Luis             2004
# Juan             2008
# Jose             2012
# Santiago         2014
#
# dfEmpleadoGrupo1a.join(dfEmpleadoAnioIngreso2a)
#                      Grupo  AnioIngreso
# Empleado
# Juan          Contabilidad         2008
# Jose            Ingeniería         2012
# Luis            Ingeniería         2004
# Santiago  Recursos Humanos         2014

# %% [markdown]
# Se pueden combinar indices y columnas

# %%
display('dfEmpleadoGrupo1a'), display('dfNombreSalario3'),  "pd.merge(dfEmpleadoGrupo1a, dfNombreSalario3, left_index=True, right_on='Nombre')"
# Out:
# (dfEmpleadoGrupo1a
#                       Grupo
#  Empleado
#  Juan          Contabilidad
#  Jose            Ingeniería
#  Luis            Ingeniería
#  Santiago  Recursos Humanos,
#  dfNombreSalario3
#       Nombre  Salario
#  0      Juan    70000
#  1      Jose    80000
#  2      Luis   120000
#  3  Santiago    90000,
#  "pd.merge(dfEmpleadoGrupo1a, dfNombreSalario3, left_index=True, right_on='Nombre')")

# %%
display('dfEmpleadoGrupo1a')
# Out:
# dfEmpleadoGrupo1a
#                      Grupo
# Empleado
# Juan          Contabilidad
# Jose            Ingeniería
# Luis            Ingeniería
# Santiago  Recursos Humanos

# %%
display('dfEmpleadoGrupo1a', 'dfMergeGrupoAnioIngreso3', "pd.merge(dfEmpleadoGrupo1a, dfMergeGrupoAnioIngreso3, left_index=True, right_on='Empleado')")
# Out:
# dfEmpleadoGrupo1a
#                      Grupo
# Empleado
# Juan          Contabilidad
# Jose            Ingeniería
# Luis            Ingeniería
# Santiago  Recursos Humanos
#
# dfMergeGrupoAnioIngreso3
#    Empleado             Grupo  AnioIngreso
# 0      Juan      Contabilidad         2008
# 1      Jose        Ingeniería         2012
# 2      Luis        Ingeniería         2004
# 3  Santiago  Recursos Humanos         2014
#
# pd.merge(dfEmpleadoGrupo1a, dfMergeGrupoAnioIngreso3, left_index=True, right_on='Empleado')
#             Grupo_x  Empleado           Grupo_y  AnioIngreso
# 0      Contabilidad      Juan      Contabilidad         2008
# 1        Ingeniería      Jose        Ingeniería         2012
# 2        Ingeniería      Luis        Ingeniería         2004
# 3  Recursos Humanos  Santiago  Recursos Humanos         2014

# %% [markdown]
# El detalle del merge se puede ver en la documentación de panda (http://pandas.pydata.org/pandas-docs/stable/merging.html) .

# %%
df6 = pd.DataFrame({'nombre': ['Pedro', 'Pablo', 'Maria'],
                    'comida': ['pescado', 'frijo', 'pan']},
                   columns=['nombre', 'comida'])
df7 = pd.DataFrame({'nombre': ['Maria', 'Jose'],
                    'bebida': ['vino', 'cerveza']},
                   columns=['nombre', 'bebida'])
display('df6', 'df7', 'pd.merge(df6, df7)')
# Out:
# df6
#   nombre   comida
# 0  Pedro  pescado
# 1  Pablo    frijo
# 2  Maria      pan
#
# df7
#   nombre   bebida
# 0  Maria     vino
# 1   Jose  cerveza
#
# pd.merge(df6, df7)
#   nombre comida bebida
# 0  Maria    pan   vino

# %% [markdown]
# Sólo tienen en común a María

# %%
pd.merge(df6, df7, how='inner')
# Out:
#   nombre comida bebida
# 0  Maria    pan   vino

# %% [markdown]
# Otras opciones para el ``how`` = ``'outer'``, ``'left'``, y ``'right'``. Outer toma todos los datos y llena con nulos los datos vacios

# %%
display('df6', 'df7', "pd.merge(df6, df7, how='outer')")
# Out:
# df6
#   nombre   comida
# 0  Pedro  pescado
# 1  Pablo    frijo
# 2  Maria      pan
#
# df7
#   nombre   bebida
# 0  Maria     vino
# 1   Jose  cerveza
#
# pd.merge(df6, df7, how='outer')
#   nombre   comida   bebida
# 0  Pedro  pescado      NaN
# 1  Pablo    frijo      NaN
# 2  Maria      pan     vino
# 3   Jose      NaN  cerveza

# %% [markdown]
#  *left join* y  *right join*

# %%
display('df6', 'df7', "pd.merge(df6, df7, how='left')")
# Out:
# df6
#   nombre   comida
# 0  Pedro  pescado
# 1  Pablo    frijo
# 2  Maria      pan
#
# df7
#   nombre   bebida
# 0  Maria     vino
# 1   Jose  cerveza
#
# pd.merge(df6, df7, how='left')
#   nombre   comida bebida
# 0  Pedro  pescado    NaN
# 1  Pablo    frijo    NaN
# 2  Maria      pan   vino

# %%
display('df6', 'df7', "pd.merge(df6, df7, how='right')")
# Out:
# df6
#   nombre   comida
# 0  Pedro  pescado
# 1  Pablo    frijo
# 2  Maria      pan
#
# df7
#   nombre   bebida
# 0  Maria     vino
# 1   Jose  cerveza
#
# pd.merge(df6, df7, how='right')
#   nombre comida   bebida
# 0  Maria    pan     vino
# 1   Jose    NaN  cerveza

# %% [markdown]
# Conflicto en el nombre de las columnas

# %%
df8 = pd.DataFrame({'nombre': ['Alberto', 'Juan', 'Luis', 'Santiago'],
                    'ranking': [1, 2, 3, 4]})
df9 = pd.DataFrame({'nombre': ['Alberto', 'Juan', 'Luis', 'Santiago'],
                    'ranking': [3, 1, 4, 2]})
display('df8', 'df9', 'pd.merge(df8, df9, on=["nombre", "ranking"])')
# Out:
# df8
#      nombre  ranking
# 0   Alberto        1
# 1      Juan        2
# 2      Luis        3
# 3  Santiago        4
#
# df9
#      nombre  ranking
# 0   Alberto        3
# 1      Juan        1
# 2      Luis        4
# 3  Santiago        2
#
# pd.merge(df8, df9, on=["nombre", "ranking"])
# Empty DataFrame
# Columns: [nombre, ranking]
# Index: []

# %%
display('df8', 'df9', 'pd.merge(df8, df9, on=["nombre"])')
# Out:
# df8
#      nombre  ranking
# 0   Alberto        1
# 1      Juan        2
# 2      Luis        3
# 3  Santiago        4
#
# df9
#      nombre  ranking
# 0   Alberto        3
# 1      Juan        1
# 2      Luis        4
# 3  Santiago        2
#
# pd.merge(df8, df9, on=["nombre"])
#      nombre  ranking_x  ranking_y
# 0   Alberto          1          3
# 1      Juan          2          1
# 2      Luis          3          4
# 3  Santiago          4          2

# %%
display('df8', 'df9', 'pd.merge(df8, df9, on="nombre", suffixes=["_L", "_R"])')
# Out:
# df8
#      nombre  ranking
# 0   Alberto        1
# 1      Juan        2
# 2      Luis        3
# 3  Santiago        4
#
# df9
#      nombre  ranking
# 0   Alberto        3
# 1      Juan        1
# 2      Luis        4
# 3  Santiago        2
#
# pd.merge(df8, df9, on="nombre", suffixes=["_L", "_R"])
#      nombre  ranking_L  ranking_R
# 0   Alberto          1          3
# 1      Juan          2          1
# 2      Luis          3          4
# 3  Santiago          4          2
