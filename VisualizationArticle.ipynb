# %% [markdown]
# <a href="https://colab.research.google.com/github/cam2149/eda_couse/blob/Unidad1/VisualizationArticle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###### Reading data using read_csv() function

# %%
df=pd.read_csv('/content/sample_data/iris.csv')

# %% [markdown]
# ###### Displaying the DataFrame

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Crear la lista de nombres para el encabezado
headers = ["Sepal_length","Sepal_width","Petal_length","Petal_width","Variety"]
print("encabezados\n", headers)
# Out:
# encabezados
#  ['Sepal_length', 'Sepal_width', 'Petal_length', 'Petal_width', 'Variety']

# %%
df.columns = headers
df.head(10)
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width Variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# 5           5.4          3.9           1.7          0.4  Setosa
# 6           4.6          3.4           1.4          0.3  Setosa
# 7           5.0          3.4           1.5          0.2  Setosa
# 8           4.4          2.9           1.4          0.2  Setosa
# 9           4.9          3.1           1.5          0.1  Setosa

# %%
df.Sepal_length.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: Sepal_length, dtype: float64

# %% [markdown]
# ###### Finding the data types of variables in the DataFrame

# %%
df.dtypes
# Out:
# Sepal_length    float64
# Sepal_width     float64
# Petal_length    float64
# Petal_width     float64
# Variety          object
# dtype: object

# %% [markdown]
# ###### Importing libraries essential for data visualization

# %%
#MATPLOTLIB
import matplotlib.pyplot as plt
# %matplotlib inline
#SEABORN
import seaborn as sns

# %% [markdown]
# ## Plots for continuous variables' analysis

# %% [markdown]
# ### ENUMERATIVE PLOTS

# %% [markdown]
# ###### UNIVARIATE SCATTER PLOT

# %%
plt.scatter(df.index,df['Sepal_width'])
plt.show()

# %%
sns.scatterplot(x=df.index,y=df['Sepal_width'],hue=df['Variety'])
# Out:
# <Axes: xlabel='None', ylabel='Sepal_width'>

# %% [markdown]
# ###### LINE PLOT WITH MARKERS

# %% [markdown]
# ###### Setting title, figure size, labels and font size in matplotlib

# %%
plt.figure(figsize=(6,6))
plt.title('Line plot of petal length')
plt.xlabel('index',fontsize=20)
plt.ylabel('petal length',fontsize=20)
plt.plot(df.index,df['Petal_length'],markevery=1,marker='d')
for name, group in df.groupby('Variety'):
    plt.plot(group.index, group['Petal_length'], label=name,markevery=1,marker='d')
plt.legend()
plt.show()

# %% [markdown]
# ###### Setting title, figure size,labels and font size in seaborn

# %%
sns.set(rc={'figure.figsize':(7,7)})
sns.set(font_scale=1.5)

# %%
fig=sns.lineplot(x=df.index,y=df['Petal_length'],markevery=1,marker='d',data=df,hue=df['Variety'])
fig.set(xlabel='index')
# Out:
# [Text(0.5, 0, 'index')]

# %% [markdown]
# ###### STRIP PLOT

# %%
sns.stripplot(y=df['Sepal_width'])
# Out:
# <Axes: ylabel='Sepal_width'>

# %%
# Strip-plot(category wise)
sns.stripplot(x=df['Variety'],y=df['Sepal_width'])
# Out:
# <Axes: xlabel='Variety', ylabel='Sepal_width'>

# %% [markdown]
# ###### SWARM PLOT

# %%
#Setting figure size
sns.set(rc={'figure.figsize':(5,5)})
#Swarm-plot
sns.swarmplot(x=df['Sepal_width'])
# Out:
# <Axes: xlabel='Sepal_width'>

# %%
#Swarm-plot category wise
sns.swarmplot(x=df['Variety'],y=df['Sepal_width'])
# Out:
# <Axes: xlabel='Variety', ylabel='Sepal_width'>

# %% [markdown]
# ### SUMMARY PLOTS

# %% [markdown]
# ###### HISTOGRAM

# %%
plt.hist(df['Petal_width'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['Petal_width'],kde=False,color='black',bins=10)
# Out:
# <ipython-input-35-2d51e5ba88ba>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Petal_width'],kde=False,color='black',bins=10)
# <Axes: xlabel='Petal_width'>

# %% [markdown]
# ###### DENSITY PLOT

# %%
plt.figure(figsize=(5,5))
df['Petal_length'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.kdeplot(df['Petal_length'],shade=True)
# Out:
# <ipython-input-37-e909c96600aa>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Petal_length'],shade=True)
# <Axes: xlabel='Petal_length', ylabel='Density'>

# %% [markdown]
# ###### RUG PLOT

# %%
fig, ax = plt.subplots()
sns.rugplot(df['Sepal_length'])
ax.set_xlim(3,9)
plt.show()

# %%
from scipy import stats
import numpy as np
kdf=df['Sepal_length'].to_numpy()
rdf=np.hstack(kdf)
density = stats.kde.gaussian_kde(rdf)
x = np.arange(3,9,0.1)
plt.plot(x, density(x))
plt.plot(rdf,[0.01]*len(rdf), '|')
# Out:
# <ipython-input-39-3689916a59c4>:5: DeprecationWarning: Please import `gaussian_kde` from the `scipy.stats` namespace; the `scipy.stats.kde` namespace is deprecated and will be removed in SciPy 2.0.0.
#   density = stats.kde.gaussian_kde(rdf)

# %%
sns.distplot(df['Sepal_length'],rug=True,hist=False)
# Out:
# <ipython-input-40-24ca3dc874bc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sepal_length'],rug=True,hist=False)
# <Axes: xlabel='Sepal_length', ylabel='Density'>

# %% [markdown]
# ###### BOX PLOT

# %%
plt.boxplot(df['Sepal_width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7cec2dbbb6d0>,
#   <matplotlib.lines.Line2D at 0x7cec2dbbb970>],
#  'caps': [<matplotlib.lines.Line2D at 0x7cec2dbbbc10>,
#   <matplotlib.lines.Line2D at 0x7cec2dbbbeb0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7cec2dbbb430>],
#  'medians': [<matplotlib.lines.Line2D at 0x7cec2dbf8190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7cec2dbf8430>],
#  'means': []}

# %% [markdown]
# ###### Removing the column with categorical variables

# %%
dfM=df.drop('Variety',axis=1)

# %%
plt.figure(figsize=(9,9))
#Set Title
plt.title('Box plots of the 4 variables')
plt.boxplot(dfM.values,labels=['SepalLength','SepalWidth','PetalLength','PetalWidth'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7cec2da39750>,
#   <matplotlib.lines.Line2D at 0x7cec2da399f0>,
#   <matplotlib.lines.Line2D at 0x7cec2da3a9b0>,
#   <matplotlib.lines.Line2D at 0x7cec2da3ac50>,
#   <matplotlib.lines.Line2D at 0x7cec2da3bc10>,
#   <matplotlib.lines.Line2D at 0x7cec2da3beb0>,
#   <matplotlib.lines.Line2D at 0x7cec2da7ceb0>,
#   <matplotlib.lines.Line2D at 0x7cec2da7d150>],
#  'caps': [<matplotlib.lines.Line2D at 0x7cec2da39c90>,
#   <matplotlib.lines.Line2D at 0x7cec2da39f30>,
#   <matplotlib.lines.Line2D at 0x7cec2da3aef0>,
#   <matplotlib.lines.Line2D at 0x7cec2da3b190>,
#   <matplotlib.lines.Line2D at 0x7cec2da7c190>,
#   <matplotlib.lines.Line2D at 0x7cec2da7c430>,
#   <matplotlib.lines.Line2D at 0x7cec2da7d3f0>,
#   <matplotlib.lines.Line2D at 0x7cec2da7d690>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7cec2da394b0>,
#   <matplotlib.lines.Line2D at 0x7cec2da3a710>,
#   <matplotlib.lines.Line2D at 0x7cec2da3b970>,
#   <matplotlib.lines.Line2D at 0x7cec2da7cc10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7cec2da3a1d0>,
#   <matplotlib.lines.Line2D at 0x7cec2da3b430>,
#   <matplotlib.lines.Line2D at 0x7cec2da7c6d0>,
#   <matplotlib.lines.Line2D at 0x7cec2da7d930>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7cec2da3a470>,
#   <matplotlib.lines.Line2D at 0x7cec2da3b6d0>,
#   <matplotlib.lines.Line2D at 0x7cec2da7c970>,
#   <matplotlib.lines.Line2D at 0x7cec2da7dbd0>],
#  'means': []}

# %%
sns.boxplot(df['Sepal_width'])
# Out:
# <Axes: ylabel='Sepal_width'>

# %%
sns.set(rc={'figure.figsize':(9,9)})
sns.boxplot(x="variable", y="value", data=pd.melt(dfM))
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %% [markdown]
# ###### distplot()

# %%
sns.set(rc={'figure.figsize':(6,6)})
sns.distplot(df['Petal_length'],color='black',rug=True)
# Out:
# <ipython-input-48-ecb2a4006c77>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Petal_length'],color='black',rug=True)
# <Axes: xlabel='Petal_length', ylabel='Density'>

# %% [markdown]
# ###### VIOLIN PLOT

# %%
plt.figure(figsize=(7,7))
plt.violinplot(dfM.values,showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7cec79216c20>,
#   <matplotlib.collections.PolyCollection at 0x7cec2d420b80>,
#   <matplotlib.collections.PolyCollection at 0x7cec2d420ee0>,
#   <matplotlib.collections.PolyCollection at 0x7cec2d421240>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7cec792e8a30>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7cec791f8df0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7cec791b9cc0>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x7cec791957b0>}

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.violinplot(df['Sepal_width'],orient='vertical')
# Out:
# <Axes: ylabel='Sepal_width'>

# %%
sns.set(rc={'figure.figsize':(9,9)})
sns.violinplot(x=df['Variety'], y=df['Petal_width'],data=df)
# Out:
# <Axes: xlabel='Variety', ylabel='Petal_width'>

# %% [markdown]
# ## Plots for categorical variables' analysis

# %% [markdown]
# ###### BAR PLOT

# %%
df['Variety'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Variety'>

# %%
sns.countplot(df['Variety'])
# Out:
# <Axes: xlabel='count', ylabel='Variety'>

# %% [markdown]
# ###### PIE CHART

# %%
plt.pie(df['Variety'].value_counts(),labels=['Setosa','Versicolor','Virginica'],shadow=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x7cec31eb60e0>,
#   <matplotlib.patches.Wedge at 0x7cec31eb5ff0>,
#   <matplotlib.patches.Wedge at 0x7cec31eb6890>],
#  [Text(0.5499999702695115, 0.9526279613277875, 'Setosa'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'Versicolor'),
#   Text(0.5500001486524352, -0.9526278583383436, 'Virginica')])

# %%
df1=df.sample(frac=0.35)

# %%
plt.figure(figsize=(5,5))
plt.pie(df1['Variety'].value_counts(),startangle=90,autopct='%.2f',labels=['Setosa','Versicolor','Virginica'],shadow=False)
# Out:
# ([<matplotlib.patches.Wedge at 0x7cec31d701f0>,
#   <matplotlib.patches.Wedge at 0x7cec31d70100>,
#   <matplotlib.patches.Wedge at 0x7cec31d71240>],
#  [Text(-0.9740016429451693, 0.5111954611888794, 'Setosa'),
#   Text(0.1325904426548767, -1.0919797500487745, 'Versicolor'),
#   Text(0.9052821579754744, 0.6248713583220699, 'Virginica')],
#  [Text(-0.5312736234246378, 0.2788338879212069, '34.62'),
#   Text(0.07232205962993274, -0.5956253182084223, '34.62'),
#   Text(0.4937902679866223, 0.340838922721129, '30.77')])
